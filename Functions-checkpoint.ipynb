# %% [markdown]
# - Reuse any part of ccode
# *****without arguments****

# %%
n1=10
n2=20
add=n1+n2
print("the addition of {} and {} is {}".format(n1,n2,add))
# Out:
# the addition of 10 and 20 is 30

# %%
def <function_name>():
    #write your code here

# %%
def addition():
    n1=10
    n2=20
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))

# %%
#the output is not display untill unless you call the function
#pythhon will take only latest one

# %%
addition()
# Out:
# the addition of 10 and 20 is 30

# %%
def anu():
    print("hello")
    print("i am writing function")

# %%
anu()
# Out:
# hello
# i am writing function

# %%
def hello():
    n1=eval(input("enter the number"))
    print("hello")
    print("i am writing function")

# %%
hello()
# Out:
# enter the number7
# hello
# i am writing function

# %%
#in this particular cell :500 lines
- if you are not mentioning any values inside the function bracket
- with out arguments out parameters
- arguments or parameters

# %%
n1=100

# %%
n2=200

# %%
print(n1+n2)
# Out:
# 300

# %%
def hello_world():
    print("hello good morning")
    
hello_world()
# Out:
# hello good morning

# %%
hello_world()
# Out:
# hello good morning

# %%
#take three numbers find the average
#wap ask the user enter 3 numbers
#n1=eval(input())
#n3=eval(input())
#n3=eval(input())
#avg=(n1+n2+n3)/3
#first write normal code
#then implement the function

# %%
def avg():
    num1=eval(input("enter number1: "))
    num2=eval(input("enter number2: "))
    num3=eval(input("enter number3: "))
    average=(num1+num2+num3)/3
    print("average of {}, {} and {} is {}: ".format(num1,num2,num3,average))

# %% [markdown]
# avg()note:
#     we are not sure, the function is defined correct or wrong
#     untill unless we call the function

# %% [markdown]
# # note:
#     we are not sure, the function is defined correct or wrong
#     untill unless we call the function

# %%
def avg1():
    try:  
        num1=eval(input("enter number1: "))
        num2=eval(input("enter number2: "))
        num3=eval(input("enter number3: "))
        average=(num1+num2+num3333)/3
        print("average of {}, {} and {} is {}: ".format(num1,num2,num3,average))
    except Exception as e:
        print(e)
        
avg1()
# Out:
# enter number1: 40
# enter number2: 10
# enter number3: 5
# name 'num3333' is not defined

# %%
#wap ask the user enter bill amount
#wap ask the user enter the tip amount
#wap calculate the total
def total():
    try:
        num1=eval(input("enter the bill amount: "))
        num2=eval(input("enter the tip amount: "))
        total=num1+num2
        print("the total bill {} and {} is {}: ".format(num1,num2,total))
    except Exception as e:
        print(e)
        
total()
# Out:
# enter the bill amount: 1000
# enter the tip amount: 100
# the total bill 1000 and 100 is 1100:

# %%
#wap ask the user get a random number between 1 to 100 
#print it is even or odd number
#Implement using function
import random
def even_odd1():
    print("we are implementing even or odd number: ")
    print("take one number: ")
    num=random.randint(1,100)
    if num%2==0:
        print("{} is an even number".format(num))
    else:
        print("{} is an odd number".format(num))
    
even_odd1()
# Out:
# we are implementing even or odd number:
# take one number:
# 83 is an odd number

# %%
import random
def even_odd2():
    try:
        print("we are implementing even or odd number: ")
        print("take one number: ")
        num=random.randint(1,100)
        if num%2==0:
            print("the reminder is zero")
            print("{} is an even number".format(num))
        else:
            print("the reminder is not zero")
            print("{} is an odd number".format(num))
    except Exception as e:
        print(e)
        
even_odd1()
# Out:
# we are implementing even or odd number:
# take one number:
# 86 is an even number

# %%
import random
print("hello")
print('python')
def even_odd1():
    try:
        print("we are implementing even or odd number: ")
        print("take one number: ")
        num=random.randint(1,100)
        if num%2==0:
            print("{} is an even number".format(num))
        else:
            print("{} is an odd number".format(num))
    except Exception as e:
        print(e)
print("calling function") 
even_odd1() 
print("done!")
# Out:
# hello
# python
# calling function
# we are implementing even or odd number:
# take one number:
# 91 is an odd number
# done!

# %%
def addition():
    n1=20
    n2=30
    print('addition: ',n1+n2)
    
print('mul function: ',n1*n2)
def mul():
    n1=20
    n2=30
    print('mul: ',n1*n2)
    print('mul is done!')
    
print('sub function: ',n1-n2)
def sub():
    n1=20
    n2=30
    print('sub: ',n1-n2)
    print('sub is done!')
    
print("anything remains")
print("no")
print("then call the function")
# Out:
# mul function:  20000
# sub function:  -100
# anything remains
# no
# then call the function

# %% [markdown]
#  ******with arguments*******

# %%
def addition(n1,n2):
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
    
addition(70,40)
# Out:
# the addition of 70 and 40 is 110

# %%
def addition(n1,n2):
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
    
addition(40,40)
# Out:
# the addition of 40 and 40 is 80

# %%
def addition(n1,n2):
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
    
addition(40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 5
#       2     add=n1+n2
#       3     print("the addition of {} and {} is {}".format(n1,n2,add))
# ----> 5 addition(40)
#
# TypeError: addition() missing 1 required positional argument: 'n2'

# %%
def addition111():
    add=n111+n222
    print("the addition of {} and {} is {}".format(n1,n2,add))
    
addition11()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 5
#       2     add=n111+n222
#       3     print("the addition of {} and {} is {}".format(n1,n2,add))
# ----> 5 addition11()
#
# NameError: name 'addition11' is not defined

# %%
def addition11():
    add=n111+n222
    print("the addition of {} and {} is {}".format(n1,n2,add))
    
addition(200,400)
# Out:
# the addition of 200 and 400 is 600

# %%
def addition11():
    add=n111+n222
    print("the addition of {} and {} is {}".format(n1,n2,add))
    
addition11(70,40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 5
#       2     add=n111+n222
#       3     print("the addition of {} and {} is {}".format(n1,n2,add))
# ----> 5 addition11(70,40)
#
# TypeError: addition11() takes 0 positional arguments but 2 were given

# %%
#implement code with arguments
def avg(num1,num2,num3):
    average=(num1+num2+num3)/3
    print("average of {}, {} and {} is {}: ".format(num1,num2,num3,average))#implement code with arguments

avg(10,20,30)
# Out:
# average of 10, 20 and 30 is 20.0:

# %%
def avg(num1,num2,num3):
    print("num1: ",num1)
    print("num2: ",num2)
    print("num3: ",num3)
    average=(num1+num2+num3)/3
    print("average of {}, {} and {} is {}: ".format(num1,num2,num3,average))

avg(10,20,30)
# Out:
# num1:  10
# num2:  20
# num3:  30
# average of 10, 20 and 30 is 20.0:

# %%
num=int(input('enter number'))
v1=num%10
v11=num//10
v11
# Out:
# enter number10
# 1

# %% [markdown]
# ***default parameters***

# %%
# tax percentage is always=20
# fixed
# default parameters

# %%
def tax_cal(salary,tax_per=20):
    total_tax=salary*tax_per/100
    print("the total tax is:",total_tax)
tax_cal(5000)
# Out:
# the total tax is: 1000.0

# %%
def avg(num1,num2,num3):
    add=(num1+num2+num3)
    avg=add/3
    print("the avg is:",avg)
avg(20,30,40)
# Out:
# the avg is: 30.0

# %%
def avg(num1,num2,num3=50):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    add=(num1+num2+num3)
    avg=add/3
    print("the avg is:",avg)
avg(20,30)
# Out:
# num1: 20
# num2: 30
# num3: 50
# the avg is: 33.333333333333336

# %%
num1,num2,num3=100
print(num1,num2,num3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 num1,num2,num3=100
#       2 print(num1,num2,num3)
#
# TypeError: cannot unpack non-iterable int object

# %%
def avg(num1,num3,num2=500):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    add=(num1+num2+num3)
    avg=add/3
    print("the avg is:",avg)
avg(200,300)
# Out:
# num1: 200
# num2: 500
# num3: 300
# the avg is: 333.3333333333333

# %%
def avg(num1,num3=500,num2):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    add=(num1+num2+num3)
    avg=add/3
    print("the avg is:",avg)
avg(200,300)
# Out:
#   Cell In[8], line 1
#     def avg(num1,num3=500,num2):
#                           ^
# SyntaxError: non-default argument follows default argument

# %%
num1,num2,num3=3000=======valid
num1,num2=500,num3
num1,num2,num3=
num1,num2,num3=

# %%
def avg(num1,num3=500,num2):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    num3=800
    add=(num1+num2+num3)
    avg=add/3
    print("the avg is:",avg)
avg(200,300,600)

# while defining the functon: num3=50
# while you are calling fun num3=60
# after enter inside the fun num3=800

# %% [markdown]
# .with out arguments .with arguments .default arguments
#
# -import random random.randint()
#
# -complex()#not provide:default
#
# -from random import randint randint(10,20)

# %% [markdown]
# **function=method**

# %%
def sum(a,b):
    print(a*b)
sum(10,20)
# Out:
# 200

# %%
# wap ask the user to find area of circle
# basic method
# without arguments
# with arguments
# defaault arguments

# %%
import math

# %%
import math 
def area_of_circle(r):
    pi=math.pi
    area1=round(pi*r*r,2)
    print("the area of circle is:", area1)
r=eval(input("enter radius"))
area_of_circle(r)

# import math
# define fun
# getting the r value
# call the fun
#inside the fun getting the value 
#                           area1
#                           print
# Out:
# enter radius7
# the area of circle is: 153.94

# %%
import math 
def area_of_circle(r):
    pi=math.pi
    area1=round(pi*r*r,2)
    print("the area of is:", area1)
pii=math.pi
area_of_circle(pii)
# Out:
# the area of is: 31.01

# %%
import math 
def area_of_circle():
    pi=math.pi
    r= eval(input("enter the radius"))
    area11=round(pi*r*r,2)
    print("the area of circle is:", area11)
area_of_circle()
# Out:
# enter the radius7
# the area of circle is: 153.94

# %% [markdown]
# **return the values**

# %%
import math 
def area_of_circle():
    pi=math.pi
    r= eval(input("enter the radius"))
    area11=round(pi*r*r,2)
    print("the area of circle is:", area11)
    return(area11,pii)

# %%
Area,pii=area_of_circle()


# area_of_circle() will return the two values
# area11,pii
# area will store in a variable:Area
# pii will store in a variables
# Out:
# enter the radius7
# the area of circle is: 153.94

# %%
pii=
# Out:
#   Cell In[25], line 1
#     pii=
#         ^
# SyntaxError: invalid syntax

# %%
import math 
def area_of_circle():
    pi=math.pi
    r= eval(input("enter the radius"))
    area11=round(pi*r*r,2)
    print("the area of circle is:", area11)
    return(area11,pii)
Area,pi=area_of_circle()
print(Area)
print(pii)
# Out:
# enter the radius12
# the area of circle is: 452.39
# 452.39
# 3.141592653589793

# %%
# ask the user enter 3 number
# find the sum and average
# return the average value and sum both

# %%
def sum_avg():
    num1=eval(input("enter a num1:"))
    num2=eval(input("enter a num2:"))
    num3=eval(input("enter a num3:"))
    sum=num1+num2+num3
    print("sum:",sum)
    print("avg:",avg)
    return(sum,avg)
sum_avg()
# Out:
# enter a num1:10
# enter a num2:20
# enter a num3:30
# sum: 60
# avg: <function avg at 0x000002729498C400>
# (60, <function __main__.avg(num1, num3, num2=500)>)

# %%
def sum_avg(n1,n2,n3):
    sum=(n1+n2+n3)
    avg=sum/3
    print("sum:",sum)
    print("avg:",avg)
    return(sum,avg)
addition,avg=sum_avg(20,30,40)
# Out:
# sum: 90
# avg: 30.0

# %%
# find the biggest number of 3 number
# take and 3 number
# and find the biggest number
# and return that number

# %%
def biggest_num():
    num1=eval(input("enter a num1:"))
    num2=eval(input("enter a num2:"))
    num3=eval(input("enter a num3:"))
    if num1>num2 and num1>num3:
        print("num1 is greater num")
        return(num1)
    elif num2>num3:
        print("num2 is greater num")
        return(num2)
    else:
        print("num3 is greater num")
        return(num3)
biggest_num()
# Out:
# enter a num1:7
# enter a num2:2
# enter a num3:8
# num3 is greater num
# 8

# %%
def add(a,b):
    return(a+b)
def sub(a,b):
    return(a-b)
def mul(a,b):
    return(a*b)
def div(a,b):
    return(a/b)
10
# Out:
# 10

# %%
def aggregation(a,b):
    return(a+b,a-b,a*b,a/b)
add,sub,mul,div=aggregation(30,50)
print(add,sub,mul,round(div,2))
# Out:
# 80 -20 1500 0.6

# %%
def aggregation(a,b):
    return(a+b,a-b,a*b,a/b)
value=aggregation(30,50)
value
# Out:
# (80, -20, 1500, 0.6)

# %%
def add(a,b): return(a+b)
def sub(a,b): return(a-b)
def mul(a,b): return(a*b)
def div(a,b): return(a/b)
val_add=add(20,30)
val_sub=sub(20,30)
val_mul=mul(20,30)
val_div=div(20,30)
print(val_add,val_sub,val_mul,val_div,round(val_div,2))
# Out:
# 50 -10 600 0.6666666666666666 0.67

# %% [markdown]
# -with out arguments
# -with arguments
# -Default arguments
# -return statements

# %% [markdown]
# *****Local variables******

# %%
**local variables:**
    The variables provided inside the function
Global vvariables:
    The variables provided outside the function

# %%
**global variables**   #outside the function
n1=10
n2=20
def addition():
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
    
addition()

**local variables**  #inside the function
def addition():
    n1=10
    n2=20
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
    
addition()

# %%
def avg():
    num1=10
    num2=20
    num3=30
    avg=(num1+num2+num3)/3
    print("the average of {},{} and {} is {}".format(num1,num2,num3,avg))
    
avg()
# Out:
# the average of 10,20 and 30 is 20.0

# %%
num1=10
num2=20
num3=30
def avg():
    avg=(num1+num2+num3)/3
    print("the average of {},{} and {} is {}".format(num1,num2,num3,avg))
    
avg()
# Out:
# the average of 10,20 and 30 is 20.0

# %%
def avg():
    num1=10
    num2=20
    num3=30
    avg=(num1+num2+num3)/3
    print("the average of {},{} and {} is {}".format(num1,num2222,num3,avg))

avg()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 8
#       5     avg=(num1+num2+num3)/3
#       6     print("the average of {},{} and {} is {}".format(num1,num2222,num3,avg))
# ----> 8 avg()
#
# Cell In[12], line 6, in avg()
#       4 num3=30
#       5 avg=(num1+num2+num3)/3
# ----> 6 print("the average of {},{} and {} is {}".format(num1,num2222,num3,avg))
#
# NameError: name 'num2222' is not defined

# %%
def avg():
    num11=10
    num22=20
    num33=30
    avg=(num1+num2+num3)/3
    print("the average of {},{} and {} is {}".format(num1,num2,num3,avg))
    return(num11)

val11=avg()

# %%
def avg():
    num11=10
    num22=20
    num33=30
    avg=(num1+num2+num3)/3
    print("the average of {},{} and {} is {}".format(num1,num2,num3,avg))
    return(num11,num22)

val11,val22=avg()
# Out:
# the average of 10,20 and 30 is 20.0

# %% [markdown]
# .local variables are inside the function
# .global variables are outside the function

# %%
num11=10
num22=20
num33=30
def avg():
    avg=(num1+num2+num3)/3
    print("the average of {},{} and {} is {}".format(num11,num22,num33,avg))
    return(num11,num22)

val11,val22=avg()

print(num11*num22)
# Out:
# the average of 10,20 and 30 is 20.0
# 200

# %%
n1=10
n2=20
def addition():
    n1=100
    n2=200
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
    
addition()

print(n1)
# Out:
# the addition of 100 and 200 is 300
# 10

# %%
n1=10
n2=20
def addition():
    n2=200
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
    
addition()

print(n1)
# Out:
# the addition of 10 and 200 is 210
# 10

# %%
n1=10
n2=20
def addition(n1=700):
    n1=100
    n2=200
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
    
addition()

print(n1)
# Out:
# the addition of 100 and 200 is 300
# 10

# %%
num1=eval(input("enter the 1st no:"))
num2=eval(input("enter the 2nd no:"))
num3=eval(input("enter the 3rd no:"))
if num2<num1<num3:
    print(num1,"is the greatest number")
    a=num1
elif num2>num3:
    print(num2,"is the greatest number")
    a=num1
else:
    print(num3,"is the greatest number")
    a=num3
return(a)
# Out:
# enter the 1st no:
# Traceback (most recent call last):
#
#   File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3526 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[14], line 1
#     num1=eval(input("enter the 1st no:"))
#
#   File <string>
#
#     ^
# SyntaxError: invalid syntax

# %%
#we can not use local variables values outside the function
#untill unless with out return statement
#i want to use local variables outside the function, with out using return statements

# %%
global

# %%
n1=10
def updated():
    n1=n1+100
    print("n1 value inside the function is:",n1)
    
updated()
print(n1)

#with out return the n1,we need to get the updated value
#we need to use local variable outside the function, without the return
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[19], line 6
#       3     n1=n1+100
#       4     print("n1 value inside the function is:",n1)
# ----> 6 updated()
#       7 print(n1)
#
# Cell In[19], line 3, in updated()
#       2 def updated():
# ----> 3     n1=n1+100
#       4     print("n1 value inside the function is:",n1)
#
# UnboundLocalError: cannot access local variable 'n1' where it is not associated with a value

# %%
def value():
    global number1, number2
    number1=10
    number2=20
    print(number1)
    
value()
print(number1)
print(number2)
# Out:
# 10
# 10
# 20

# %%
n_=10
def updated():
    n_=20
    n_=n_+100
    print("n1 value inside the function is:",n_)
    
updated()
print(n_)
# Out:
# n1 value inside the function is: 120
# 10

# %%
n1=10
n2=20
def addition(n1):
    n2=200
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
    
addition(500)

print(n2)
print(add)
# Out:
# the addition of 500 and 200 is 700
# 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 11
#       8 addition(500)
#      10 print(n2)
# ---> 11 print(add)
#
# NameError: name 'add' is not defined

# %%
n1=10
n2=20
def addition(n1):
    global n2,add
    n2=200
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
    
addition(500)

print(n2)
print(add)
# Out:
# the addition of 500 and 200 is 700
# 200
# 700

# %% [markdown]
# **function in function**

# %%
def greet():
    print("hello")

def name():
    print("python")
    
greet()
name()
# Out:
# hello
# python

# %%
def greet():           #def greet
    print("hello")

def name():            #def name
    print("python")    #calling function
    greet()            #python
                       #calling function
name()                 #hello
# Out:
# python
# hello

# %%
def greet():           #def greet
    print("hello")

def name():            #def name
    print("python")    #calling function
    print("how do you do")
    
greet()
name()
# Out:
# hello
# python
# how do you do

# %%
def greet():           
    print("hello")
    name()
    
def name():            
    print("python")    
                       
greet()
# Out:
# hello
# python

# %%
def greet():           
    print("hello")
    name()
    
def name():            
    print("python")    
    greet()
    
greet()
print("----------")
name()
# Out:
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# ...

# %%
print(3)

def fun1():
    print("hello")
    print("python")
    
print("10+10")
def fun2():
    print("3+5")
    print(3+5)
    fun1()
    print("good")
    
print(10+10)
def fun3():
    fun1()
    fun2()

fun3()
# Out:
# 3
# 10+10
# 20
# hello
# python
# 3+5
# 8
# hello
# python
# good

# %%
#create four functions
#def add(a+b)
#    print(a+b)
#sub
#mul
#div
#you need to provide some print statements 
    #if you want enter1: addition operation will come
    #if you want to enter2: subtract
    #if you enter3: mul
    #if you enter4: div
    #operator=input("enter a number")
    #a=eval(input())
    #b=eval(input())
    #if operation=="1":
    #   add(a,b)
    #if operation=="2":
    #   sub(a,b)
    #if operation=="3":
    #   mul(a,b)
def add(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def mul(a,b):    
    print(a*b)
def div(a,b):   
    print(a/b)
def main():
    num=eval(input("enter a number: "))
    a=eval(input("enter a number1: "))
    b=eval(input("enter a number2: "))
    if num==1:
        add(a,b)
    elif num==2:
        suba,b()
    elif num==3:
        mul(a,b)
    else:
        div(a,b)
        
main()
# Out:
# enter a number: 10
# enter a number1: 20
# enter a number2: 30
# 0.6666666666666666
